# %%
import pandas as pd
import numpy as np

# %%
COLUMN_MAP = {
    "ASA52 Index": "AEQ",
    "NDDLWI Index": "ILE_H",
    "NDLEEGF Index": "ILE_UH",
    "RDAU Index": "ALP",
    "FDCIISAH Index": "ILP_H",
    "HEDGNAV Index": "ILI_H",
    "BACM0 Index": "AFI",
    "H03432AU Index": "IFI_H",
    "BAUBIL Index": "CASH"
}

ASSET_COLUMNS = [asset_name for asset_name in COLUMN_MAP.values()]

# %%
GROWTH_ASSETS = [ASSET_COLUMNS[i] for i in range(len(ASSET_COLUMNS) - 3)]
GROWTH_ASSETS
# Out:
# ['AEQ', 'ILE_H', 'ILE_UH', 'ALP', 'ILP_H', 'ILI_H']

# %%
[ASSET_COLUMNS[i] for i in range(len(ASSET_COLUMNS)-3, len(ASSET_COLUMNS))]
# Out:
# ['AFI', 'IFI_H', 'CASH']

# %%
[ASSET_COLUMNS[i] for i in range(3)]
# Out:
# ['AEQ', 'ILE_H', 'ILE_UH']
